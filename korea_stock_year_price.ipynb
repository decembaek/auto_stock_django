# %%
import os
from pathlib import Path
import django
import pandas as pd


from dotenv import load_dotenv

load_dotenv()
# env = environ.Env()
import json
import requests
import time

# %%
APP_KEY = os.environ.get("APP_KEY")
APP_SECRET = os.environ.get("APP_SECRET")
TEST_APP_KEY = os.environ.get("TEST_APP_KEY")
TEST_APP_SECRET = os.environ.get("TEST_APP_SECRET")
# Build paths inside the project like this: BASE_DIR / 'subdir'.
REAL_URL_BASE = "https://openapi.koreainvestment.com:9443"
TEST_URL_BASE = "https://openapivts.koreainvestment.com:29443"

REALTIME_WEBSOCKET_URL = "/oauth2/Approval"
TOKEN_URL = "/oauth2/tokenP"
PRICE_URL = "/uapi/domestic-stock/v1/quotations/inquire-daily-itemchartprice"

# %%
json_headers = {"content-type": "application/json"}
token_body = {
    "grant_type": "client_credentials",
    "appkey": APP_KEY,
    "appsecret": APP_SECRET,
}

# TOKEN 발급이 필요하면 True로 하기
token_bool = False

if token_bool:
    token_res = requests.post(
        REAL_URL_BASE + TOKEN_URL,
        headers=json_headers,
        data=json.dumps(token_body),
        # timeout 요청 시간 제한
        timeout=10,
    )

    ACCESS_TOKEN = token_res.json()["access_token"]
    # JSON 파일로 저장
    with open("ACCESS_TOKEN.json", "w") as json_file:
        json.dump({"ACCESS_TOKEN": ACCESS_TOKEN}, json_file, indent=4)
else:
    with open("ACCESS_TOKEN.json", "r") as json_file:
        data = json.load(json_file)
        ACCESS_TOKEN = data["ACCESS_TOKEN"]

# %%
headers = {
    "content-type": "application/json",
    "authorization": "Bearer " + ACCESS_TOKEN,
    "appkey": APP_KEY,
    "appsecret": APP_SECRET,
    "tr_id": "FHKST03010100",
}
params = {
    "FID_COND_MRKT_DIV_CODE": "J",
    "FID_INPUT_ISCD": "000020",
    "FID_INPUT_DATE_1": "20000101",
    "FID_INPUT_DATE_2": "20231231",
    "FID_PERIOD_DIV_CODE": "Y",
    "FID_ORG_ADJ_PRC": "0",
}

# %%
res = requests.get(
    REAL_URL_BASE + PRICE_URL,
    headers=headers,
    params=params,
    timeout=10,
)

# %%
res.json()
# Out:
# {'output1': {'prdy_vrss': '-30',
#   'prdy_vrss_sign': '5',
#   'prdy_ctrt': '-0.30',
#   'stck_prdy_clpr': '9870',
#   'acml_vol': '63449',
#   'acml_tr_pbmn': '625140950',
#   'hts_kor_isnm': '동화약품',
#   'stck_prpr': '9840',
#   'stck_shrn_iscd': '000020',
#   'prdy_vol': '45460',
#   'stck_mxpr': '12830',
#   'stck_llam': '6910',
#   'stck_oprc': '9850',
#   'stck_hgpr': '9910',
#   'stck_lwpr': '9830',
#   'stck_prdy_oprc': '9940',
#   'stck_prdy_hgpr': '9970',
#   'stck_prdy_lwpr': '9820',
#   'askp': '9850',
#   'bidp': '9840',
#   'prdy_vrss_vol': '17989',
#   'vol_tnrt': '0.23',
#   'stck_fcam': '1000',
#   'lstn_stcn': '27931470',
#   'cpfn': '279',
#   'hts_avls': '2748',
#   'per': '13.48',
#   'eps': '730.00',
#   'pbr': '0.75',
#   'itewhol_loan_rmnd_ratem name': '1.92'},
#  'output2': [{'stck_bsop_date': '20231228',
#    'stck_clpr': '10270',
#    'stck_oprc': '9400',
#    'stck_hgpr': '11120',
#    'stck_lwpr': '8070',
#    'acml_vol': '24687853',
#    'acml_tr_pbmn': '239629865790',
#    'flng_cls_code': '00',
#    'prtt_rate': '0.00',
#    'mod_yn': 'N',
#    'prdy_vrss_sign': '2',
#    'prdy_vrss': '1010',
#    'revl_issu_reas': ''},
#   {'stck_bsop_date': '20221229',
#    'stck_clpr': '9260',
#    'stck_oprc': '14800',
#    'stck_hgpr': '15350',
#    'stck_lwpr': '8060',
#    'acml_vol': '40998214',
#    'acml_tr_pbmn': '484644692080',
#    'flng_cls_code': '00',
#    'prtt_rate': '0.00',
#    'mod_yn': 'N',
#    'prdy_vrss_sign': '5',
#    'prdy_vrss': '-5340',
#    'revl_issu_reas': ''},
#   {'stck_bsop_date': '20211230',
#    'stck_clpr': '14600',
#    'stck_oprc': '19750',
#    'stck_hgpr': '21550',
#    'stck_lwpr': '13400',
#    'acml_vol': '209817692',
#    'acml_tr_pbmn': '3658218673250',
#    'flng_cls_code': '00',
#    'prtt_rate': '0.00',
#    'mod_yn': 'N',
#    'prdy_vrss_sign': '5',
#    'prdy_vrss': '-5050',
#    'revl_issu_reas': ''},
#   {'stck_bsop_date': '20201230',
#    'stck_clpr': '19650',
#    'stck_oprc': '8340',
#    'stck_hgpr': '34450',
#    'stck_lwpr': '4800',
#    'acml_vol': '378603361',
#    'acml_tr_pbmn': '7243626991135',
#    'flng_cls_code': '00',
#    'prtt_rate': '0.00',
#    'mod_yn': 'N',
#    'prdy_vrss_sign': '2',
#    'prdy_vrss': '11340',
#    'revl_issu_reas': ''},
#   {'stck_bsop_date': '20191230',
#    'stck_clpr': '8310',
#    'stck_oprc': '9190',
#    'stck_hgpr': '10300',
#    'stck_lwpr': '7500',
#    'acml_vol': '22652024',
#    'acml_tr_pbmn': '197965184300',
#    'flng_cls_code': '00',
#    'prtt_rate': '0.00',
#    'mod_yn': 'N',
#    'prdy_vrss_sign': '5',
#    'prdy_vrss': '-790',
#    'revl_issu_reas': ''},
#   {'stck_bsop_date': '20181228',
#    'stck_clpr': '9100',
#    'stck_oprc': '9750',
#    'stck_hgpr': '13400',
#    'stck_lwpr': '7500',
#    'acml_vol': '46713393',
#    'acml_tr_pbmn': '524531928930',
#    'flng_cls_code': '00',
#    'prtt_rate': '0.00',
#    'mod_yn': 'N',
#    'prdy_vrss_sign': '5',
#    'prdy_vrss': '-650',
#    'revl_issu_reas': ''},
#   {'stck_bsop_date': '20171228',
#    'stck_clpr': '9750',
#    'stck_oprc': '8160',
#    'stck_hgpr': '11550',
#    'stck_lwpr': '7790',
#    'acml_vol': '33875649',
#    'acml_tr_pbmn': '314630226480',
#    'flng_cls_code': '00',
#    'prtt_rate': '0.00',
#    'mod_yn': 'N',
#    'prdy_vrss_sign': '2',
#    'prdy_vrss': '1630',
#    'revl_issu_reas': ''},
#   {'stck_bsop_date': '20161229',
#    'stck_clpr': '8120',
#    'stck_oprc': '8130',
#    'stck_hgpr': '11950',
#    'stck_lwpr': '7060',
#    'acml_vol': '72074781',
#    'acml_tr_pbmn': '678265099570',
#    'flng_cls_code': '00',
#    'prtt_rate': '0.00',
#    'mod_yn': 'N',
#    'prdy_vrss_sign': '5',
#    'prdy_vrss': '-20',
#    'revl_issu_reas': ''},
#   {'stck_bsop_date': '20151230',
#    'stck_clpr': '8140',
#    'stck_oprc': '5450',
#    'stck_hgpr': '12250',
#    'stck_lwpr': '5400',
#    'acml_vol': '54304424',
#    'acml_tr_pbmn': '468312986660',
#    'flng_cls_code': '00',
#    'prtt_rate': '0.00',
#    'mod_yn': 'N',
#    'prdy_vrss_sign': '2',
#    'prdy_vrss': '2570',
#    'revl_issu_reas': ''},
#   {'stck_bsop_date': '20141230',
#    'stck_clpr': '5570',
#    'stck_oprc': '4440',
#    'stck_hgpr': '6560',
#    'stck_lwpr': '4410',
#    'acml_vol': '20925838',
#    'acml_tr_pbmn': '114816661840',
#    'flng_cls_code': '00',
#    'prtt_rate': '0.00',
#    'mod_yn': 'N',
#    'prdy_vrss_sign': '2',
#    'prdy_vrss': '1180',
#    'revl_issu_reas': ''},
#   {'stck_bsop_date': '20131230',
#    'stck_clpr': '4390',
#    'stck_oprc': '6070',
#    'stck_hgpr': '7420',
#    'stck_lwpr': '4315',
#    'acml_vol': '20256240',
#    'acml_tr_pbmn': '124317448830',
#    'flng_cls_code': '00',
#    'prtt_rate': '0.00',
#    'mod_yn': 'N',
#    'prdy_vrss_sign': '5',
#    'prdy_vrss': '-1650',
#    'revl_issu_reas': ''},
#   {'stck_bsop_date': '20121228',
#    'stck_clpr': '6040',
#    'stck_oprc': '4070',
#    'stck_hgpr': '6800',
#    'stck_lwpr': '4060',
#    'acml_vol': '32035524',
#    'acml_tr_pbmn': '175849366405',
#    'flng_cls_code': '00',
#    'prtt_rate': '0.00',
#    'mod_yn': 'N',
#    'prdy_vrss_sign': '2',
#    'prdy_vrss': '1960',
#    'revl_issu_reas': ''},
#   {'stck_bsop_date': '20111229',
#    'stck_clpr': '4080',
#    'stck_oprc': '5320',
#    'stck_hgpr': '6470',
#    'stck_lwpr': '3860',
#    'acml_vol': '35915126',
#    'acml_tr_pbmn': '179514906590',
#    'flng_cls_code': '00',
#    'prtt_rate': '0.00',
#    'mod_yn': 'N',
#    'prdy_vrss_sign': '5',
#    'prdy_vrss': '-1210',
#    'revl_issu_reas': ''},
#   {'stck_bsop_date': '20101230',
#    'stck_clpr': '5290',
#    'stck_oprc': '7540',
#    'stck_hgpr': '7820',
#    'stck_lwpr': '4580',
#    'acml_vol': '24897148',
#    'acml_tr_pbmn': '141536752210',
#    'flng_cls_code': '00',
#    'prtt_rate': '0.00',
#    'mod_yn': 'N',
#    'prdy_vrss_sign': '5',
#    'prdy_vrss': '-2290',
#    'revl_issu_reas': ''},
#   {'stck_bsop_date': '20091230',
#    'stck_clpr': '7580',
#    'stck_oprc': '6200',
#    'stck_hgpr': '10400',
#    'stck_lwpr': '6000',
#    'acml_vol': '59388695',
#    'acml_tr_pbmn': '476907101210',
#    'flng_cls_code': '00',
#    'prtt_rate': '0.00',
#    'mod_yn': 'N',
#    'prdy_vrss_sign': '2',
#    'prdy_vrss': '1400',
#    'revl_issu_reas': ''},
#   {'stck_bsop_date': '20081230',
#    'stck_clpr': '6180',
#    'stck_oprc': '10740',
#    'stck_hgpr': '13720',
#    'stck_lwpr': '3560',
#    'acml_vol': '33745457',
#    'acml_tr_pbmn': '262185509850',
#    'flng_cls_code': '00',
#    'prtt_rate': '0.00',
#    'mod_yn': 'N',
#    'prdy_vrss_sign': '5',
#    'prdy_vrss': '-4540',
#    'revl_issu_reas': ''},
#   {'stck_bsop_date': '20071228',
#    'stck_clpr': '10720',
#    'stck_oprc': '6410',
#    'stck_hgpr': '20000',
#    'stck_lwpr': '5100',
#    'acml_vol': '46299579',
#    'acml_tr_pbmn': '571073024250',
#    'flng_cls_code': '00',
#    'prtt_rate': '0.00',
#    'mod_yn': 'N',
#    'prdy_vrss_sign': '2',
#    'prdy_vrss': '4260',
#    'revl_issu_reas': ''},
#   {'stck_bsop_date': '20061228',
#    'stck_clpr': '6460',
#    'stck_oprc': '3740',
#    'stck_hgpr': '6690',
#    'stck_lwpr': '2800',
#    'acml_vol': '66857723',
#    'acml_tr_pbmn': '328730166550',
#    'flng_cls_code': '00',
#    'prtt_rate': '0.00',
#    'mod_yn': 'N',
#    'prdy_vrss_sign': '2',
#    'prdy_vrss': '2710',
#    'revl_issu_reas': ''},
#   {'stck_bsop_date': '20051229',
#    'stck_clpr': '3750',
#    'stck_oprc': '1688',
#    'stck_hgpr': '5060',
#    'stck_lwpr': '1688',
#    'acml_vol': '140063591',
#    'acml_tr_pbmn': '477363346700',
#    'flng_cls_code': '00',
#    'prtt_rate': '0.00',
#    'mod_yn': 'N',
#    'prdy_vrss_sign': '2',
#    'prdy_vrss': '2064',
#    'revl_issu_reas': ''},
#   {'stck_bsop_date': '20041230',
#    'stck_clpr': '1686',
#    'stck_oprc': '1344',
#    'stck_hgpr': '1908',
#    'stck_lwpr': '1202',
#    'acml_vol': '30524656',
#    'acml_tr_pbmn': '46488174470',
#    'flng_cls_code': '00',
#    'prtt_rate': '0.00',
#    'mod_yn': 'N',
#    'prdy_vrss_sign': '2',
#    'prdy_vrss': '336',
#    'revl_issu_reas': ''},
#   {'stck_bsop_date': '20031230',
#    'stck_clpr': '1350',
#    'stck_oprc': '1302',
#    'stck_hgpr': '2040',
#    'stck_lwpr': '1162',
#    'acml_vol': '48024703',
#    'acml_tr_pbmn': '69110673200',
#    'flng_cls_code': '00',
#    'prtt_rate': '0.00',
#    'mod_yn': 'N',
#    'prdy_vrss_sign': '2',
#    'prdy_vrss': '48',
#    'revl_issu_reas': ''},
#   {'stck_bsop_date': '20021230',
#    'stck_clpr': '1302',
#    'stck_oprc': '1842',
#    'stck_hgpr': '2260',
#    'stck_lwpr': '1284',
#    'acml_vol': '92930861',
#    'acml_tr_pbmn': '167972254530',
#    'flng_cls_code': '00',
#    'prtt_rate': '0.00',
#    'mod_yn': 'N',
#    'prdy_vrss_sign': '5',
#    'prdy_vrss': '-536',
#    'revl_issu_reas': ''},
#   {'stck_bsop_date': '20011228',
#    'stck_clpr': '1838',
#    'stck_oprc': '1321',
#    'stck_hgpr': '2510',
#    'stck_lwpr': '1168',
#    'acml_vol': '288723300',
#    'acml_tr_pbmn': '538344129100',
#    'flng_cls_code': '00',
#    'prtt_rate': '0.00',
#    'mod_yn': 'N',
#    'prdy_vrss_sign': '2',
#    'prdy_vrss': '603',
#    'revl_issu_reas': ''},
#   {'stck_bsop_date': '20001226',
#    'stck_clpr': '1235',
#    'stck_oprc': '2662',
#    'stck_hgpr': '4211',
#    'stck_lwpr': '1224',
#    'acml_vol': '307672133',
#    'acml_tr_pbmn': '758103262000',
#    'flng_cls_code': '00',
#    'prtt_rate': '0.00',
#    'mod_yn': 'N',
#    'prdy_vrss_sign': '5',
#    'prdy_vrss': '-1475',
#    'revl_issu_reas': ''}],
#  'rt_cd': '0',
#  'msg_cd': 'MCA00000',
#  'msg1': '정상처리 되었습니다.'}
